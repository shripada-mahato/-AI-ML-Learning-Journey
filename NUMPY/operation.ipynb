# %%
def my(x):
    return x * 2
    print(my)
my(my(my(my(2))))

# %%
import numpy as np
arr = [10,20,30]
nparr = np.not_equal(10)
print(nparr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 import numpy as np
#       2 arr = [10,20,30]
# ----> 3 nparr = np.not_equal(10)
#       4 print(nparr)
#
# TypeError: not_equal() takes from 2 to 3 positional arguments but 1 were given
